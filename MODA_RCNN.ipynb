# %% [markdown]
# ### CTA Example Data Notebook
#
# By S. Spencer 30/11/2022.
#
# This notebook provides the essential data you need to be able to use the provided CTA data for your MoDAII project. The data is that from this paper: https://arxiv.org/abs/2103.06054, and consists of simulated corsika/sim_telarray event images for an array of four CTA CHEC-S/GCT telescopes at the CTA-South site in Cerro Paranal. Full QCD simulation for the protons and ray tracing simulation of the telescope optics, as well as simulation of the camera electronics and night sky background has already been performed. Your task is to use any machine learning method to separate the simulated gamma-ray events from the background events. Only a subset of the data will be provided initially, more is available if needed, as is GPU time if required.
#
# The CHEC-S camera consists of 2048 pixels in a roughly square design, so the arrays provided already have square images already suitable for use for example with CNNs. However, there are uninstrumented regions in the camera corners that are zero padded. Events which only trigger e.g. 1 of the 4 telescopes are zero padded, such that the training arrays are of the shape n_events x 4 telescopes x (48x48) pixels.
#
# There are two types of data in the files you should concern yourself with, timing histograms or charge data. If using the timing histograms these can be fed into a machine learning algorithm of choice as is, if using the charge data (actually the standard) these will need to be tailcut cleaned before processing using the *ctapipe* package available from here: https://github.com/cta-observatory/ctapipe/, but be aware you might need to use an older version of ctapipe for this to work with this data.

# %% [markdown]
# Inside the data files (all ending in .hdf5), you'll find a number of structures. First to note is the event labels, which are the truth labels for the event classes. These are 0 for gamma-ray showers, 1 for protons and 2 for electrons (in equal ratios and already randomly mixed for training/test/validation purposes). I strongly suggest you perform array operations to remove these electron events from your training/test/validation data, essentially in the paper we tried to explore if electron event classification was possible and it turns out it isn't.

# %% [markdown]
# You are free to use any machine learning algorithm you wish to classify events, and can do this parametrically (by deriving Hillas parameters from the images using ctapipe) or using deep learning methods. If using deep learning I suggest you spend some time investigating the literature on the subject (such as Shilon et al. 2018 https://arxiv.org/abs/1803.10698, which kick-started the use of deep learning for IACT event classification). You can perform deep learning on individual IACT images (by downselecting to a single telescope and then removing the zero-padded images using numpy), or attempt the more challenging task of stereoscopic image analysis (the literature describes how to do this using a mixture of CNN/RNN methods, the *Keras* package API can help you to do this). What is not permitted is to add the individual IACT images together and then feed them into a DNN per-event, this is very bad and known not to work.

# %% [markdown]
# If investigating deep learning, you're unlikely to be able to fit the complete dataset into a GPU with a model at once. You'll need to investigate using data generators or tf.datasets to be able to train a network with sufficient data to get good results.

# %%
#!pip install tables

# %%
import tables
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, utils
import keras
import numpy as np
import os
import pandas as pd

# %%
hist_json_file = 'history_rcnn.json'
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)#Set the GPU for training
nepochs = 32#definine the number of epochs
np.random.seed(15234589)

# %%
class RCNN(tf.keras.Model):#writing a class that inherits  from tf.keras.Model
    def __init__(self, dropoutRate = 0.3):
        """
        RCNN Model for binary classification.
        -----------
        Parameters:
            dropoutRate (float): The dropout rate for regularization (default=0.4)
            input_shape (tuple): The input shape of the data (default=(4, 48, 48))
        -----------
        Returns:
            None
        """
        super(RCNN, self).__init__()
        #define the layers
        self.input_layer = layers.Input((4, 48, 48, 1))
        self.norm0 = layers.BatchNormalization()
        self.conf1 = layers.ConvLSTM2D(2, 5, return_sequences=True, data_format='channels_last')
        self.relu1 = tf.keras.layers.LeakyReLU()
        self.drop1 = layers.Dropout(dropoutRate)
        self.norm1 = layers.BatchNormalization()
        
        self.conf2 = layers.ConvLSTM2D(4, 5, return_sequences=True, data_format='channels_last')
        self.relu2 = tf.keras.layers.LeakyReLU()
        self.drop2 = layers.Dropout(dropoutRate)
        self.norm2 = layers.BatchNormalization()
        
        self.conf3 = layers.ConvLSTM2D(8, 5, return_sequences=True, data_format='channels_last')
        self.relu3 = tf.keras.layers.LeakyReLU()
        self.drop3 = layers.Dropout(dropoutRate)
        self.norm3 = layers.BatchNormalization()
        
        self.conf4 = layers.ConvLSTM2D(16, 5, return_sequences=False, data_format='channels_last')
        self.relu4 = tf.keras.layers.LeakyReLU()
        self.drop4 = layers.Dropout(dropoutRate)
        self.norm4 = layers.BatchNormalization()  
        
        self.flat = layers.Flatten()
        self.fc1 = layers.Dense(1)
        self.out = self.call(self.input_layer)

    def call(self, inputs, training = True):
        """
        Define the forward pass of the CNN model.
        -----------
        Parameters:
            inputs (tf.Tensor): The input data
            training (bool): Whether or not the model is being called during training (default=True)
        ---------
        Returns:
            The output of the model
        """
        x = self.norm0(inputs, training)
        x = self.drop1(self.relu1(self.conf1(x)), training)
        x = self.norm1(x, training)
        x = self.drop2(self.relu2(self.conf2(x)), training)
        x = self.norm2(x, training)
        x = self.drop3(self.relu3(self.conf3(x)), training)
        x = self.norm3(x, training)
        x = self.drop4(self.relu4(self.conf4(x)), training)
        x = self.norm4(x, training)
    
        x = self.flat(x)
        return tf.math.sigmoid(self.fc1(x))
    
    def build_graph(self):
        """
        Builds a new `tf.keras.Model` instance with the current instance of `CNN` as the model definition.
        Just only for plotting
        # !!!doesnt work if the model was loaded!!!
        -----------
        Parameters:
            None
        -----------
        Returns:
            tf.keras.Model like the current instance
        """
        return tf.keras.Model(inputs=[self.input_layer], outputs=self.call(self.input_layer))

# %%
def data_reader(training_split = .3):
    """
    Reads data from fife HDF5 files in the current directory and returns three sets of data for training, testing,
    and validation.

    Args:
        training_split (float): The fraction of the data to be used for testing and validation, 
        the test and validation data are approximatly evenly splited.

    Returns:
        A tuple containing:
            - A numpy array of training data.
            - A numpy array of training labels.
            - A numpy array of test data.
            - A numpy array of test labels.
            - A numpy array of validation data.
            - A numpy array of validation labels.
    """
    data, data_label = [], []
    data_length = 0
    for i in os.listdir():#list all files of the current folder
        if '.hdf5' in i:#check if this is a file of hd5f type
            x=tables.open_file(i,'r')
            data_label = np.concatenate((data_label, x.root.event_label[:])) #concatenate the labels
            data_length +=len(x.root.event_label[:])
            if len(data) != 0:#if one wats to concatenate(([], x.root.squared_training[:])) there will be an exception as the shape dirffers 
                data = np.concatenate((data, x.root.squared_training[:]), axis = 0)
            else:
                data = x.root.squared_training[:]
            x.close()#closing the files
            del x#garbage collecting
            
    mask = data_label[:] != 2#doing the trainingsplit
    data, data_label = data[mask], data_label[mask]        
    
    mask = training_split < np.random.rand(len(data_label))
    training, training_label = data[mask], data_label[mask]
    new_data, new_label = data[~mask], data_label[~mask]
    
    mask = .5 < np.random.rand(len(new_label))#doing the validation, test split
    test, test_label, val, val_label = new_data[mask], new_label[mask], new_data[~mask], new_label[~mask]
    
    del data, data_label, new_data, new_label#garbage collecting
    return training, training_label, test, test_label, val, val_label

# %%
training, training_label, test, test_label, val, val_label = data_reader()
training = tf.expand_dims(training, 4)
test = tf.expand_dims(test, 4)
val = tf.expand_dims(val, 4)
#read the data, and expand dims. the expand_dims, as cannels
print(f"length of training data: {len(training_label)} with {np.sum(training_label):.0f} protons events")
print(f"length of test data: {len(test_label)} with {np.sum(test_label):.0f} protons events")
print(f"length of validation data: {len(val_label)} with {np.sum(val_label):.0f} protons events")
# Out:
# length of training data: 46574 with 23249 protons events
# length of test data: 9974 with 4975 protons events
# length of validation data: 10089 with 5101 protons events

# %%
try:#if there already exists a model, load this
    model = tf.keras.models.load_model('moda_network_rcnn.tf')
    model.compile(optimizer=tf.keras.optimizers.Adam(),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[tf.keras.metrics.BinaryAccuracy(),
                tf.keras.metrics.FalseNegatives(),
                tf.keras.metrics.FalsePositives()])
except OSError:#otherwise create a new and train it
    model = RCNN()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[tf.keras.metrics.BinaryAccuracy(),
                tf.keras.metrics.FalseNegatives(),
                tf.keras.metrics.FalsePositives()])

    history = model.fit(x = training, #train the model
                    y = training_label,
                    epochs=nepochs,
                    shuffle = True,#shuffls the data after each epoch
                    batch_size = 128,
                    validation_data = (val, val_label)
                    )
    hist_df = pd.DataFrame(history.history)  
    with open(hist_json_file, mode='w') as f:#save the history
        hist_df.to_json(f)
    history = history.history
    model.save('moda_network_rcnn.tf')#save the model
    
history = pd.read_json(hist_json_file)#load the history
# Out:
# Epoch 1/32
# 364/364 [==============================] - 142s 364ms/step - loss: 0.6245 - binary_accuracy: 0.6674 - false_negatives: 7987.0000 - false_positives: 7504.0000 - val_loss: 0.6521 - val_binary_accuracy: 0.6126 - val_false_negatives: 3799.0000 - val_false_positives: 109.0000
# Epoch 2/32
# 364/364 [==============================] - 131s 359ms/step - loss: 0.4565 - binary_accuracy: 0.7668 - false_negatives: 5487.0000 - false_positives: 5372.0000 - val_loss: 0.4068 - val_binary_accuracy: 0.7880 - val_false_negatives: 1941.0000 - val_false_positives: 198.0000
# Epoch 3/32
# 364/364 [==============================] - 129s 355ms/step - loss: 0.3887 - binary_accuracy: 0.8061 - false_negatives: 4604.0000 - false_positives: 4426.0000 - val_loss: 0.3319 - val_binary_accuracy: 0.8429 - val_false_negatives: 606.0000 - val_false_positives: 979.0000
# Epoch 4/32
# 364/364 [==============================] - 130s 358ms/step - loss: 0.3350 - binary_accuracy: 0.8385 - false_negatives: 3772.0000 - false_positives: 3749.0000 - val_loss: 0.2915 - val_binary_accuracy: 0.8768 - val_false_negatives: 799.0000 - val_false_positives: 444.0000
# Epoch 5/32
# 364/364 [==============================] - 130s 356ms/step - loss: 0.2868 - binary_accuracy: 0.8675 - false_negatives: 3122.0000 - false_positives: 3049.0000 - val_loss: 0.2203 - val_binary_accuracy: 0.9059 - val_false_negatives: 695.0000 - val_false_positives: 254.0000
# Epoch 6/32
# 364/364 [==============================] - 129s 354ms/step - loss: 0.2492 - binary_accuracy: 0.8861 - false_negatives: 2674.0000 - false_positives: 2632.0000 - val_loss: 0.1812 - val_binary_accuracy: 0.9263 - val_false_negatives: 548.0000 - val_false_positives: 196.0000
# Epoch 7/32
# 364/364 [==============================] - 130s 358ms/step - loss: 0.2090 - binary_accuracy: 0.9086 - false_negatives: 2145.0000 - false_positives: 2114.0000 - val_loss: 0.1487 - val_binary_accuracy: 0.9414 - val_false_negatives: 361.0000 - val_false_positives: 230.0000
# Epoch 8/32
# 364/364 [==============================] - 129s 355ms/step - loss: 0.1733 - binary_accuracy: 0.9268 - false_negatives: 1700.0000 - false_positives: 1709.0000 - val_loss: 0.1255 - val_binary_accuracy: 0.9515 - val_false_negatives: 241.0000 - val_false_positives: 248.0000
# Epoch 9/32
# 364/364 [==============================] - 130s 356ms/step - loss: 0.1463 - binary_accuracy: 0.9404 - false_negatives: 1435.0000 - false_positives: 1343.0000 - val_loss: 0.0790 - val_binary_accuracy: 0.9741 - val_false_negatives: 149.0000 - val_false_positives: 112.0000
# Epoch 10/32
# 364/364 [==============================] - 130s 358ms/step - loss: 0.1215 - binary_accuracy: 0.9497 - false_negatives: 1152.0000 - false_positives: 1191.0000 - val_loss: 0.0794 - val_binary_accuracy: 0.9687 - val_false_negatives: 259.0000 - val_false_positives: 57.0000
# Epoch 11/32
# 364/364 [==============================] - 129s 355ms/step - loss: 0.0979 - binary_accuracy: 0.9608 - false_negatives: 932.0000 - false_positives: 895.0000 - val_loss: 0.0620 - val_binary_accuracy: 0.9790 - val_false_negatives: 100.0000 - val_false_positives: 112.0000
# Epoch 12/32
# 364/364 [==============================] - 130s 357ms/step - loss: 0.0832 - binary_accuracy: 0.9664 - false_negatives: 778.0000 - false_positives: 785.0000 - val_loss: 0.0313 - val_binary_accuracy: 0.9908 - val_false_negatives: 50.0000 - val_false_positives: 43.0000
# Epoch 13/32
# 364/364 [==============================] - 130s 356ms/step - loss: 0.0726 - binary_accuracy: 0.9720 - false_negatives: 665.0000 - false_positives: 638.0000 - val_loss: 0.0311 - val_binary_accuracy: 0.9905 - val_false_negatives: 40.0000 - val_false_positives: 56.0000
# Epoch 14/32
# 364/364 [==============================] - 129s 355ms/step - loss: 0.0644 - binary_accuracy: 0.9753 - false_negatives: 581.0000 - false_positives: 569.0000 - val_loss: 0.0542 - val_binary_accuracy: 0.9824 - val_false_negatives: 130.0000 - val_false_positives: 48.0000
# Epoch 15/32
# 364/364 [==============================] - 130s 358ms/step - loss: 0.0592 - binary_accuracy: 0.9778 - false_negatives: 526.0000 - false_positives: 509.0000 - val_loss: 0.0240 - val_binary_accuracy: 0.9934 - val_false_negatives: 40.0000 - val_false_positives: 27.0000
# Epoch 16/32
# 364/364 [==============================] - 130s 356ms/step - loss: 0.0512 - binary_accuracy: 0.9801 - false_negatives: 456.0000 - false_positives: 470.0000 - val_loss: 0.0174 - val_binary_accuracy: 0.9952 - val_false_negatives: 24.0000 - val_false_positives: 24.0000
# Epoch 17/32
# 364/364 [==============================] - 131s 360ms/step - loss: 0.0490 - binary_accuracy: 0.9812 - false_negatives: 447.0000 - false_positives: 430.0000 - val_loss: 0.0147 - val_binary_accuracy: 0.9962 - val_false_negatives: 23.0000 - val_false_positives: 15.0000
# Epoch 18/32
# 364/364 [==============================] - 131s 359ms/step - loss: 0.0456 - binary_accuracy: 0.9821 - false_negatives: 419.0000 - false_positives: 414.0000 - val_loss: 0.0132 - val_binary_accuracy: 0.9967 - val_false_negatives: 14.0000 - val_false_positives: 19.0000
# Epoch 19/32
# 364/364 [==============================] - 131s 360ms/step - loss: 0.0402 - binary_accuracy: 0.9851 - false_negatives: 342.0000 - false_positives: 350.0000 - val_loss: 0.0155 - val_binary_accuracy: 0.9959 - val_false_negatives: 26.0000 - val_false_positives: 15.0000
# Epoch 20/32
# 364/364 [==============================] - 131s 359ms/step - loss: 0.0375 - binary_accuracy: 0.9862 - false_negatives: 325.0000 - false_positives: 318.0000 - val_loss: 0.0170 - val_binary_accuracy: 0.9959 - val_false_negatives: 12.0000 - val_false_positives: 29.0000
# Epoch 21/32
# 364/364 [==============================] - 130s 357ms/step - loss: 0.0360 - binary_accuracy: 0.9863 - false_negatives: 318.0000 - false_positives: 320.0000 - val_loss: 0.0120 - val_binary_accuracy: 0.9972 - val_false_negatives: 11.0000 - val_false_positives: 17.0000
# Epoch 22/32
# 364/364 [==============================] - 130s 357ms/step - loss: 0.0330 - binary_accuracy: 0.9878 - false_negatives: 289.0000 - false_positives: 277.0000 - val_loss: 0.0101 - val_binary_accuracy: 0.9973 - val_false_negatives: 13.0000 - val_false_positives: 14.0000
# Epoch 23/32
# 364/364 [==============================] - 133s 366ms/step - loss: 0.0315 - binary_accuracy: 0.9885 - false_negatives: 275.0000 - false_positives: 259.0000 - val_loss: 0.0077 - val_binary_accuracy: 0.9983 - val_false_negatives: 9.0000 - val_false_positives: 8.0000
# Epoch 24/32
# 364/364 [==============================] - 133s 364ms/step - loss: 0.0301 - binary_accuracy: 0.9887 - false_negatives: 264.0000 - false_positives: 261.0000 - val_loss: 0.0103 - val_binary_accuracy: 0.9968 - val_false_negatives: 13.0000 - val_false_positives: 19.0000
# Epoch 25/32
# 364/364 [==============================] - 133s 365ms/step - loss: 0.0269 - binary_accuracy: 0.9897 - false_negatives: 234.0000 - false_positives: 244.0000 - val_loss: 0.0085 - val_binary_accuracy: 0.9981 - val_false_negatives: 9.0000 - val_false_positives: 10.0000
# Epoch 26/32
# 364/364 [==============================] - 136s 374ms/step - loss: 0.0251 - binary_accuracy: 0.9908 - false_negatives: 209.0000 - false_positives: 219.0000 - val_loss: 0.0058 - val_binary_accuracy: 0.9982 - val_false_negatives: 3.0000 - val_false_positives: 15.0000
# Epoch 27/32
# 364/364 [==============================] - 133s 365ms/step - loss: 0.0231 - binary_accuracy: 0.9913 - false_negatives: 202.0000 - false_positives: 205.0000 - val_loss: 0.0074 - val_binary_accuracy: 0.9980 - val_false_negatives: 6.0000 - val_false_positives: 14.0000
# Epoch 28/32
# 364/364 [==============================] - 133s 364ms/step - loss: 0.0230 - binary_accuracy: 0.9918 - false_negatives: 201.0000 - false_positives: 180.0000 - val_loss: 0.0077 - val_binary_accuracy: 0.9979 - val_false_negatives: 6.0000 - val_false_positives: 15.0000
# Epoch 29/32
# 364/364 [==============================] - 132s 364ms/step - loss: 0.0203 - binary_accuracy: 0.9924 - false_negatives: 177.0000 - false_positives: 178.0000 - val_loss: 0.0063 - val_binary_accuracy: 0.9983 - val_false_negatives: 9.0000 - val_false_positives: 8.0000
# Epoch 30/32
# 364/364 [==============================] - 134s 368ms/step - loss: 0.0224 - binary_accuracy: 0.9923 - false_negatives: 180.0000 - false_positives: 179.0000 - val_loss: 0.0065 - val_binary_accuracy: 0.9984 - val_false_negatives: 11.0000 - val_false_positives: 5.0000
# Epoch 31/32
# 364/364 [==============================] - 133s 367ms/step - loss: 0.0182 - binary_accuracy: 0.9931 - false_negatives: 160.0000 - false_positives: 163.0000 - val_loss: 0.0084 - val_binary_accuracy: 0.9974 - val_false_negatives: 15.0000 - val_false_positives: 11.0000
# Epoch 32/32
# 364/364 [==============================] - 134s 368ms/step - loss: 0.0191 - binary_accuracy: 0.9929 - false_negatives: 168.0000 - false_positives: 162.0000 - val_loss: 0.0046 - val_binary_accuracy: 0.9984 - val_false_negatives: 3.0000 - val_false_positives: 13.0000
# INFO:tensorflow:Assets written to: moda_network_rcnn.tf\assets

# %%
model.evaluate(test, test_label)#evaluate the model

try:#model.build_graph() doesnt work if the model was loaded
    tf.keras.utils.plot_model(model.build_graph(), 'RCNN.pdf', show_layer_names=False, expand_nested=True, show_shapes = True)
    model.summary()
except AttributeError:
    print('Graph plotting doesn\'t work if the model was loaded')
# Out:
# 312/312 [==============================] - 12s 38ms/step - loss: 0.0075 - binary_accuracy: 0.9971 - false_negatives: 7.0000 - false_positives: 22.0000
# Model: "rcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 4, 48, 48, 1)     4
#  ormalization)
#
#  conv_lstm2d (ConvLSTM2D)    (None, 4, 44, 44, 2)      608
#
#  leaky_re_lu (LeakyReLU)     (None, 4, 44, 44, 2)      0
#
#  dropout (Dropout)           (None, 4, 44, 44, 2)      0
#
#  batch_normalization_1 (Batc  (None, 4, 44, 44, 2)     8
#  hNormalization)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 4, 40, 40, 4)      2416
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 4, 40, 40, 4)      0
#
#  dropout_1 (Dropout)         (None, 4, 40, 40, 4)      0
#
#  batch_normalization_2 (Batc  (None, 4, 40, 40, 4)     16
#  hNormalization)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 4, 36, 36, 8)      9632
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 4, 36, 36, 8)      0
#
#  dropout_2 (Dropout)         (None, 4, 36, 36, 8)      0
#
#  batch_normalization_3 (Batc  (None, 4, 36, 36, 8)     32
#  hNormalization)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 32, 32, 16)        38464
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32, 32, 16)        0
#
#  dropout_3 (Dropout)         (None, 32, 32, 16)        0
#
#  batch_normalization_4 (Batc  (None, 32, 32, 16)       64
#  hNormalization)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 1)                 16385
#
# =================================================================
# Total params: 67,629
# Trainable params: 67,567
# Non-trainable params: 62
# _________________________________________________________________

# %% [markdown]
# # Plots

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(np.linspace(1,nepochs,nepochs), history['binary_accuracy'], label = 'training data')
ax.plot(np.linspace(1,nepochs,nepochs),history['val_binary_accuracy'], label = 'test data')
ax.set_ylabel('accuracy')
ax.set_xlabel('epoch')
ax.legend()
ax.grid()
plt.tight_layout()
fig.savefig('model_accurancy_rcnn.pdf')

plt.show()
print('Best accuracy after {} epochs'.format(np.argmax(history['val_binary_accuracy'])+1))
# Out:
# Best accuracy after 30 epochs

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(np.linspace(1,nepochs,nepochs),history['false_negatives'], label = 'false negatives training data')
ax.plot(np.linspace(1,nepochs,nepochs),history['val_false_negatives'], label = 'false negatives test data')
ax.plot(np.linspace(1,nepochs,nepochs),history['false_positives'], label = 'false positives training data')
ax.plot(np.linspace(1,nepochs,nepochs),history['val_false_positives'], label = 'false positives test data')
ax.set_ylabel('false predictions')
ax.set_xlabel('epoch')
ax.legend()
ax.grid()
plt.tight_layout()
fig.savefig('model_false_predition_rcnn.pdf')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(np.linspace(1,nepochs-1,nepochs-1),np.diff(history['binary_accuracy']), label = 'training data')
ax.plot(np.linspace(1,nepochs-1,nepochs-1),np.diff(history['val_binary_accuracy']), label = 'test data')
ax.set_ylabel('derivation of accuracy')
ax.set_xlabel('epoch')
ax.legend()
ax.grid()
plt.tight_layout()
fig.savefig('derivation_of_model_accurancy_rcnn.pdf')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(np.linspace(1,nepochs,nepochs),history['loss'], label = 'training data')
ax.plot(np.linspace(1,nepochs,nepochs),history['val_loss'], label = 'test data')
ax.set_ylabel('loss')
ax.set_xlabel('epoch')
ax.legend()
ax.grid()
plt.tight_layout()
fig.savefig('model_loss_rcnn.pdf')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(np.linspace(1,nepochs-1,nepochs-1), np.diff(history['loss']), label = 'training data')
ax.plot(np.linspace(1,nepochs-1,nepochs-1), np.diff(history['val_loss']), label = 'test data')
ax.set_ylabel('derivaton of loss')
ax.set_xlabel('epoch')
ax.legend()
ax.grid()
plt.tight_layout()
fig.savefig('model_derivative_loss_rcnn.pdf')
plt.show()
